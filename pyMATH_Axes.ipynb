# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pyMATH</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">py<b style=color:red;>MATH</b></p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pyMATH.png"></td>
# </tr>
# </table>
#
# ----
# # `pyMATH`
#
# pyMATH, a program package for playing with math in python.

# %% [markdown]
# # Draw mathbook-type axes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi,2*np.pi,101)
y = np.sin(x)

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(10,4))
# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))
# Hide the top and right spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(10,4))
# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))
# Hide the top and right spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Draw arrows (as black triangles: ">k"/"^k") at the end of the axes.  In each
# case, one of the coordinates (0) is a data coordinate (i.e., y = 0 or x = 0,
# respectively) and the other one (1) is an axes coordinate (i.e., at the very
# right/top of the axes).  Also, disable clipping (clip_on=False) as the marker
# actually spills out of the axes.
ax.plot(1, 0, ">k", markersize=10,transform=ax.get_yaxis_transform(), clip_on=False)
ax.plot(0, 1, "^k", markersize=10,transform=ax.get_xaxis_transform(), clip_on=False)
ax.plot(x,y)

# %% [markdown]
# ----
