# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">pyMATH</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">py<b style=color:red;>MATH</b></p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# <td><img style="height: 150px;" src="images/pyMATH.png"></td>
# </tr>
# </table>
#
# ----
# # `pyMATH`
#
# pyMATH, a program package for playing with math in python.

# %% [markdown]
# ----
# ## Contents
#
# - [Introduction](xx.ipynb)
#
# - Functions
#     - [Taylor series](pyMATH_TaylorSeries.ipynb)
#     - [Polynomial functions](pyMATH_PolynomialFunctions.ipynb)
#     - [Exponential functions](pyMATH_ExponentialFunctions.ipynb)
#     - [Trigonometric functions](pyMATH_TrigonometricFunctions.ipynb)
#     - [Logistic functions](pyMATH_TrigonometricFunctions.ipynb)
#     - [Complex functions](pyMATH_LogisticFunctions.ipynb)
#
# - Differential equations
#     - [First-order ordinary DGL](pyMATH_ODEfirstorder.ipynb)
#     - [Second-order ordinary DGL](pyMATH_ODEsecondorder.ipynb)
#
# - Fourier transforms
#     - [1D Fourier transform](pyMATH_FFT1D.ipynb)
#     - [FFT of sinus functions](pyMATH_FFTsin.ipynb)
#
# - Div
#     - [Axes](pyMATH_Axes.ipynb)
#     - [Triangulate](pyMATH_Triangulate.ipynb)
#     - [AllinOne]

# %% [markdown]
# ----
